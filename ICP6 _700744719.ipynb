# Epoch 91/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5711 - acc: 0.7101
# Epoch 92/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5583 - acc: 0.7274
# Epoch 93/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5510 - acc: 0.7413
# Epoch 94/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5535 - acc: 0.7135
# Epoch 95/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5487 - acc: 0.7240
# Epoch 96/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5548 - acc: 0.7222
# Epoch 97/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5498 - acc: 0.7240
# Epoch 98/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5516 - acc: 0.7170
# Epoch 99/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5440 - acc: 0.7413
# Epoch 100/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5472 - acc: 0.7170
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                180
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 201 (804.00 Byte)
# Trainable params: 201 (804.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6547 - acc: 0.6875
# [0.6547374129295349, 0.6875]

# %%
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
import tensorflow as tf
from tensorflow.keras.layers import Dense, Activation  # You can import individual layers like Dense from keras.layers
from sklearn.model_selection import train_test_split

# load dataset
path_to_csv = '/content/gdrive/MyDrive/Colab Notebooks/diabetes.csv'
dataset = pd.read_csv(path_to_csv, header=None).values

# split dataset into training and test sets
X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)

# define the model
np.random.seed(155)
my_second_nn = Sequential()
my_second_nn.add(Dense(20, input_dim=8, activation='relu'))
my_second_nn.add(Dense(20, input_dim=8,activation='relu'))
my_second_nn.add(Dense(20, input_dim=8,activation='relu'))
my_second_nn.add(Dense(1, activation='sigmoid'))
my_second_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# train the model
my_second_nn_fitted= my_second_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)

# evaluate the model on the test set
score = my_second_nn.evaluate(X_test, Y_test, batch_size=64)
print(my_second_nn.summary())
print("Test accuracy:", score[1])
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 3ms/step - loss: 14.3060 - accuracy: 0.3385
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 2.9718 - accuracy: 0.4271
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.1790 - accuracy: 0.6580
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7967 - accuracy: 0.5920
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6888 - accuracy: 0.6250
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6694 - accuracy: 0.6476
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6482 - accuracy: 0.6736
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6298 - accuracy: 0.6701
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6262 - accuracy: 0.6736
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5957 - accuracy: 0.6771
# Epoch 11/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5811 - accuracy: 0.6910
# Epoch 12/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5745 - accuracy: 0.7049
# Epoch 13/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5722 - accuracy: 0.7049
# Epoch 14/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5780 - accuracy: 0.7205
# Epoch 15/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5812 - accuracy: 0.6944
# Epoch 16/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5665 - accuracy: 0.6927
# Epoch 17/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5608 - accuracy: 0.7309
# Epoch 18/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5558 - accuracy: 0.7205
# Epoch 19/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5577 - accuracy: 0.7240
# Epoch 20/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5559 - accuracy: 0.7292
# Epoch 21/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5436 - accuracy: 0.7431
# Epoch 22/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5426 - accuracy: 0.7483
# Epoch 23/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5498 - accuracy: 0.7257
# Epoch 24/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5393 - accuracy: 0.7552
# Epoch 25/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5444 - accuracy: 0.7361
# Epoch 26/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5223 - accuracy: 0.7517
# Epoch 27/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5343 - accuracy: 0.7639
# Epoch 28/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5401 - accuracy: 0.7326
# Epoch 29/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5238 - accuracy: 0.7396
# Epoch 30/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5237 - accuracy: 0.7552
# Epoch 31/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5468 - accuracy: 0.7292
# Epoch 32/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5324 - accuracy: 0.7535
# Epoch 33/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5154 - accuracy: 0.7535
# Epoch 34/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5180 - accuracy: 0.7587
# Epoch 35/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5471 - accuracy: 0.7431
# Epoch 36/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5514 - accuracy: 0.7344
# Epoch 37/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5190 - accuracy: 0.7448
# Epoch 38/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5131 - accuracy: 0.7622
# Epoch 39/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5113 - accuracy: 0.7587
# Epoch 40/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5026 - accuracy: 0.7465
# Epoch 41/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5125 - accuracy: 0.7587
# Epoch 42/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5014 - accuracy: 0.7604
# Epoch 43/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5519 - accuracy: 0.7396
# Epoch 44/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5428 - accuracy: 0.7413
# Epoch 45/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5249 - accuracy: 0.7413
# Epoch 46/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4993 - accuracy: 0.7726
# Epoch 47/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4916 - accuracy: 0.7708
# Epoch 48/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4986 - accuracy: 0.7552
# Epoch 49/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5142 - accuracy: 0.7448
# Epoch 50/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5312 - accuracy: 0.7344
# Epoch 51/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4975 - accuracy: 0.7587
# Epoch 52/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4861 - accuracy: 0.7830
# Epoch 53/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4972 - accuracy: 0.7396
# Epoch 54/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5030 - accuracy: 0.7569
# Epoch 55/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5231 - accuracy: 0.7257
# Epoch 56/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4990 - accuracy: 0.7674
# Epoch 57/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4892 - accuracy: 0.7778
# Epoch 58/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4753 - accuracy: 0.7760
# Epoch 59/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4825 - accuracy: 0.7726
# Epoch 60/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4820 - accuracy: 0.7691
# Epoch 61/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5130 - accuracy: 0.7413
# Epoch 62/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4999 - accuracy: 0.7656
# Epoch 63/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4977 - accuracy: 0.7656
# Epoch 64/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4866 - accuracy: 0.7587
# Epoch 65/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4727 - accuracy: 0.7812
# Epoch 66/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4841 - accuracy: 0.7604
# Epoch 67/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4871 - accuracy: 0.7604
# Epoch 68/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4814 - accuracy: 0.7743
# Epoch 69/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4765 - accuracy: 0.7778
# Epoch 70/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4803 - accuracy: 0.7691
# Epoch 71/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4806 - accuracy: 0.7656
# Epoch 72/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4858 - accuracy: 0.7708
# Epoch 73/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4846 - accuracy: 0.7674
# Epoch 74/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4758 - accuracy: 0.7708
# Epoch 75/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4727 - accuracy: 0.7743
# Epoch 76/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4691 - accuracy: 0.7691
# Epoch 77/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4735 - accuracy: 0.7674
# Epoch 78/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4714 - accuracy: 0.7743
# Epoch 79/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4896 - accuracy: 0.7656
# Epoch 80/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4705 - accuracy: 0.7726
# Epoch 81/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4782 - accuracy: 0.7726
# Epoch 82/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4790 - accuracy: 0.7708
# Epoch 83/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4737 - accuracy: 0.7656
# Epoch 84/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4678 - accuracy: 0.7760
# Epoch 85/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4669 - accuracy: 0.7691
# Epoch 86/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4886 - accuracy: 0.7639
# Epoch 87/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4861 - accuracy: 0.7622
# Epoch 88/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4738 - accuracy: 0.7778
# Epoch 89/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4710 - accuracy: 0.7778
# Epoch 90/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.7743
# Epoch 91/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4677 - accuracy: 0.7674
# Epoch 92/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4796 - accuracy: 0.7656
# Epoch 93/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4714 - accuracy: 0.7847
# Epoch 94/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4623 - accuracy: 0.7674
# Epoch 95/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4624 - accuracy: 0.7708
# Epoch 96/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4661 - accuracy: 0.7882
# Epoch 97/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4569 - accuracy: 0.7795
# Epoch 98/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4652 - accuracy: 0.7691
# Epoch 99/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4741 - accuracy: 0.7691
# Epoch 100/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4607 - accuracy: 0.7934
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5902 - accuracy: 0.7188
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 20)                180
#
#  dense_3 (Dense)             (None, 20)                420
#
#  dense_4 (Dense)             (None, 20)                420
#
#  dense_5 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 1041 (4.07 KB)
# Trainable params: 1041 (4.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Test accuracy: 0.71875

# %%
path_to_csv = '/content/gdrive/MyDrive/Colab Notebooks/breastcancer.csv'

import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense

# Load dataset
data = load_breast_cancer()

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target,
                                                    test_size=0.25, random_state=87)

# Normalize data
sc = StandardScaler()
X_train_norm = sc.fit_transform(X_train)
X_test_norm = sc.transform(X_test)

# Create model
np.random.seed(155)
model = Sequential()
model.add(Dense(20, input_dim=30, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train model
model.fit(X_train_norm, y_train, epochs=100, initial_epoch=0)

# Evaluate model on testing set
loss, accuracy = model.evaluate(X_test_norm, y_test)
print(model.summary())
print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 2s 3ms/step - loss: 0.6055 - accuracy: 0.5610
# Epoch 2/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4643 - accuracy: 0.7793
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3698 - accuracy: 0.8803
# Epoch 4/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3021 - accuracy: 0.9108
# Epoch 5/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2566 - accuracy: 0.9296
# Epoch 6/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2195 - accuracy: 0.9437
# Epoch 7/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1935 - accuracy: 0.9554
# Epoch 8/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1731 - accuracy: 0.9624
# Epoch 9/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1567 - accuracy: 0.9624
# Epoch 10/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1438 - accuracy: 0.9648
# Epoch 11/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1334 - accuracy: 0.9671
# Epoch 12/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1247 - accuracy: 0.9671
# Epoch 13/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1175 - accuracy: 0.9671
# Epoch 14/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1113 - accuracy: 0.9695
# Epoch 15/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.
(Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 641 (2.50 KB)
# Trainable params: 641 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Loss: 0.12178730219602585
# Accuracy: 0.9720279574394226

# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')
#scale data
train_data /=255.0
test_data /=255.0
#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (28, 28)
# 784
# Epoch 1/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.2933 - accuracy: 0.9096 - val_loss: 0.1449 - val_accuracy: 0.9548
# Epoch 2/10
# 235/235 [==============================] - 5s 22ms/step - loss: 0.1009 - accuracy: 0.9696 - val_loss: 0.1012 - val_accuracy: 0.9672
# Epoch 3/10
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0634 - accuracy: 0.9803 - val_loss: 0.0806 - val_accuracy: 0.9738
# Epoch 4/10
# 235/235 [==============================] - 5s 22ms/step - loss: 0.0441 - accuracy: 0.9860 - val_loss: 0.0959 - val_accuracy: 0.9718
# Epoch 5/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0328 - accuracy: 0.9895 - val_loss: 0.0624 - val_accuracy: 0.9817
# Epoch 6/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.0224 - accuracy: 0.9925 - val_loss: 0.0652 - val_accuracy: 0.9801
# Epoch 7/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.0161 - accuracy: 0.9949 - val_loss: 0.0864 - val_accuracy: 0.9777
# Epoch 8/10
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0130 - accuracy: 0.9957 - val_loss: 0.0648 - val_accuracy: 0.9828
# Epoch 9/10
# 235/235 [==============================] - 5s 22ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.1016 - val_accuracy: 0.9757
# Epoch 10/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.0756 - val_accuracy: 0.9822

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

# select a random image from test data
image_index = 1234
img = test_images[image_index]

# plot the image
plt.imshow(img, cmap='gray')

# reshape image to 1D vector
img = img.reshape((1, 784))

# normalize pixel values
img = img / 255.0

# predict class of image
result = model.predict(img)
print("Predicted digit:", np.argmax(result))
# Out:
# 1/1 [==============================] - 0s 327ms/step
# Predicted digit: 8

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))

# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.0767, Test accuracy: 0.9790
# 1 hidden layer with sigmoid - Test loss: 0.0581, Test accuracy: 0.9833
# 2 hidden layers with tanh - Test loss: 0.0795, Test accuracy: 0.9796
# 2 hidden layers with sigmoid - Test loss: 0.0640, Test accuracy: 0.9830

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))

# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.1787, Test accuracy: 0.9450
# 1 hidden layer with sigmoid - Test loss: 0.1437, Test accuracy: 0.9566
# 2 hidden layers with tanh - Test loss: 0.1389, Test accuracy: 0.9567
# 2 hidden layers with sigmoid - Test loss: 0.1060, Test accuracy: 0.9637
